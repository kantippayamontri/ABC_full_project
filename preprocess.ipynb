# %%
# !pip install icecream
# !mkdir datasets_for_train
# !mkdir datasets_for_train/digital
# !mkdir datasets_for_train/digital/train
# !mkdir datasets_for_train/digital/train/images
# !mkdir datasets_for_train/digital/train/labels

# !python preprocess.py
# Out:
# [/] CHECK digital GAUGE
# 	[/] FOLDER FOUND at datasets/digital
# [/] CHECK dial GAUGE
# 	[/] FOLDER NOT FOUND at datasets/dial
# [/] CHECK number GAUGE
# 	[/] FOLDER NOT FOUND at datasets/number
# [/] CHECK clock GAUGE
# 	[/] FOLDER NOT FOUND at datasets/clock
# [/] CHECK level GAUGE
# 	[/] FOLDER NOT FOUND at datasets/level
#
# ----------------------------------------------------------------------------------------------------
#
# --- IMPORT DATASETS FROM ROBOFLOW ---
#
# ----------------------------------------------------------------------------------------------------
#
# [-] COMBINE digital DATASET
# 	[-] COMBINE DATASET at datasets/digital
# 		[-] CHECK AT user7_231109
# 			[/] FIND train
# 			[X] CAN NOT FIND valid
# 			[X] CAN NOT FIND test
# 			[/] FIND DATA YAML FILE
# 				[-] CHECK FOR RECLASS
# 				[-] NEED TO RECLASSES
# 					[/] RECLASSES SUCCESSFUL
# 		[-] CHECK AT user14_231109
# 			[/] FIND train
# 			[X] CAN NOT FIND valid
# 			[X] CAN NOT FIND test
# ...

# %%
# !conda init bash
# !conda activate ABC
# !python train.py
# Out:
# no change     /opt/tljh/user/condabin/conda
# no change     /opt/tljh/user/bin/conda
# no change     /opt/tljh/user/bin/conda-env
# no change     /opt/tljh/user/bin/activate
# no change     /opt/tljh/user/bin/deactivate
# no change     /opt/tljh/user/etc/profile.d/conda.sh
# no change     /opt/tljh/user/etc/fish/conf.d/conda.fish
# no change     /opt/tljh/user/shell/condabin/Conda.psm1
# no change     /opt/tljh/user/shell/condabin/conda-hook.ps1
# no change     /opt/tljh/user/lib/python3.8/site-packages/xontrib/conda.xsh
# no change     /opt/tljh/user/etc/profile.d/conda.csh
# no change     /home/jupyter-g630631145/.bashrc
# No action taken.
#
# CommandNotFoundError: Your shell has not been properly configured to use 'conda activate'.
# To initialize your shell, run
#
#     $ conda init <SHELL_NAME>
#
# Currently supported shells are:
#   - bash
#   - fish
#   - tcsh
#   - xonsh
#   - zsh
#   - powershell
#
# See 'conda init --help' for more information and options.
#
# ...

# %%
import torch
from icecream import ic
ic(torch.__version__)
# !python --version

ic(torch.cuda.is_available())
# !pip list
# !echo $LD_LIBRARY_PATH
# Out:
# ic| torch.__version__: '1.13.1'
# Python 3.8.11
# ic| torch.cuda.is_available(): True
# $LD_LIBRARY_PATH:/usr/lib/x86_64-linux-gnu:/usr/lib/python3/dist-packages/tensorflow:/opt/tljh/user/lib
